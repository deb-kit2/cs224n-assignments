# %% [markdown]
# <a href="https://colab.research.google.com/github/deb-kit2/cs224n-assignments/blob/main/a4/cs224n_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, output
drive.mount("/content/drive")

import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/cs224n/a4/")
# Out:
# Mounted at /content/drive

# %%
# !pip install sentencepiece
# !pip install sacrebleu
# Out:
# ...
#      |████████████████████████████████| 1.2MB 29.2MB/s
# ...
#      |████████████████████████████████| 61kB 7.6MB/s
# ...

# %%
# !python sanity_check.py 1d
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Running Sanity Check for Question 1d: Encode
# --------------------------------------------------------------------------------
# enc_hiddens Sanity Checks Passed!
# dec_init_state[0] Sanity Checks Passed!
# dec_init_state[1] Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1d: Encode!
# --------------------------------------------------------------------------------

# %%
# !python sanity_check.py 1e
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1e: Decode
# --------------------------------------------------------------------------------
# torch.Size([23, 5, 3])
# combined_outputs Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1e: Decode!
# --------------------------------------------------------------------------------

# %%
# !python sanity_check.py 1f
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1f: Step
# --------------------------------------------------------------------------------
# dec_state[0] Sanity Checks Passed!
# dec_state[1] Sanity Checks Passed!
# combined_output  Sanity Checks Passed!
# e_t Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1f: Step!
# --------------------------------------------------------------------------------

# %%
# !sh run.sh vocab
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# read in source sentences: ./chr_en_data/train.chr
# read in target sentences: ./chr_en_data/train.en
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./chr_en_data/train.chr
#   input_format:
#   model_prefix: src
#   model_type: UNIGRAM
#   vocab_size: 21000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
# ...

# %%
# !sh run.sh train
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 208.01, avg. ppl 3244.92 cum. examples 320, speed 3560.38 words/sec, time elapsed 2.31 sec
# epoch 1, iter 20, avg. loss 178.15, avg. ppl 766.64 cum. examples 640, speed 3556.40 words/sec, time elapsed 4.73 sec
# epoch 1, iter 30, avg. loss 164.59, avg. ppl 531.78 cum. examples 960, speed 3356.08 words/sec, time elapsed 7.23 sec
# epoch 1, iter 40, avg. loss 170.55, avg. ppl 471.33 cum. examples 1280, speed 3292.55 words/sec, time elapsed 9.92 sec
# epoch 1, iter 50, avg. loss 162.17, avg. ppl 369.45 cum. examples 1600, speed 3714.32 words/sec, time elapsed 12.28 sec
# epoch 1, iter 60, avg. loss 153.30, avg. ppl 338.82 cum. examples 1920, speed 3661.77 words/sec, time elapsed 14.58 sec
# ...

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./chr_en_data/test.chr]
# load test target sentences from [./chr_en_data/test.en]
# load model from model.bin
# Decoding: 100% 1000/1000 [00:55<00:00, 17.98it/s]
# Corpus BLEU: 12.268864665861905
