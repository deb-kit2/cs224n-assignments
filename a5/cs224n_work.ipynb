# %% [markdown]
# <a href="https://colab.research.google.com/github/deb-kit2/cs224n-assignments/blob/main/a5/cs224n_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, output
drive.mount("/content/drive")

import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/cs224n/a5/student-new/")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Part d

# %%
# !python3 src/run.py finetune vanilla wiki.txt --writing_params_path vanilla.model.params --finetune_corpus_path birth_places_train.tsv
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 7: train loss 3.49886. lr 5.999844e-04: 100% 8/8 [00:05<00:00,  1.49it/s]
# epoch 2 iter 7: train loss 2.66423. lr 5.999351e-04: 100% 8/8 [00:05<00:00,  1.56it/s]
# epoch 3 iter 7: train loss 2.33394. lr 5.998521e-04: 100% 8/8 [00:05<00:00,  1.59it/s]
# epoch 4 iter 7: train loss 2.18157. lr 5.997352e-04: 100% 8/8 [00:05<00:00,  1.57it/s]
# epoch 5 iter 7: train loss 2.08739. lr 5.995847e-04: 100% 8/8 [00:05<00:00,  1.56it/s]
# ...

# %%
# !python3 src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.model.params --eval_corpus_path birth_dev.tsv --outputs_path vanilla.nopretrain.dev.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# 500it [00:41, 12.13it/s]
# Correct: 10.0 out of 500.0: 2.0%

# %%
# !python3 src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.model.params --eval_corpus_path birth_test_inputs.tsv --outputs_path vanilla.nopretrain.test.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# 437it [00:38, 11.45it/s]
# No gold birth places provided; returning (0,0)
# Predictions written to vanilla.nopretrain.test.predictions; no targets provided

# %%
# !python3 src/london_baseline.py
# Out:
# Correct: 25.0 out of 500.0: 5.0%

# %% [markdown]
# ## Part e

# %%
# !python3 src/dataset.py charcorruption
# Out:
# data has 418352 characters, 256 unique.
# x: Khatchig Mouradian. Khatchig Mouradian is a journalist, writer and translator born in⁇.⁇ Lebanon □□□□□□□□□□□□□□□□□□□□□□□□□□□□□□
# y: hatchig Mouradian. Khatchig Mouradian is a journalist, writer and translator born in⁇.⁇ Lebanon □□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□
# x: Jacob Henry ⁇gust 1904 New York City) ⁇Studer. Jacob Henry Studer (26 February 1840 Columbus, Ohio - 2 Au□□□□□□□□□□□□□□□□□□□□□□
# y: acob Henry ⁇gust 1904 New York City) ⁇Studer. Jacob Henry Studer (26 February 1840 Columbus, Ohio - 2 Au□□□□□□□□□□□□□□□□□□□□□□□
# x: John St⁇phe⁇e□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□
# y: ohn St⁇phe⁇e□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□
# x: Georgina Willis. Georgina Willis i⁇o was⁇s an award winning film director wh□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□□
# ...

# %% [markdown]
# ## Part f

# %%
# !python3 src/run.py pretrain vanilla wiki.txt --writing_params_path vanilla.pretrain.params
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# data has 418351 characters, 256 unique.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 22: train loss 3.43666. lr 5.999656e-03: 100% 23/23 [00:03<00:00,  6.08it/s]
# epoch 2 iter 22: train loss 3.39747. lr 5.998583e-03: 100% 23/23 [00:03<00:00,  6.29it/s]
# epoch 3 iter 22: train loss 3.02103. lr 5.996782e-03: 100% 23/23 [00:03<00:00,  6.26it/s]
# epoch 4 iter 22: train loss 2.86790. lr 5.994254e-03: 100% 23/23 [00:03<00:00,  6.24it/s]
# ...

# %%
# !python3 src/run.py finetune vanilla wiki.txt --reading_params_path vanilla.pretrain.params --writing_params_path vanilla.finetune.params --finetune_corpus_path birth_places_train.tsv
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 7: train loss 0.72482. lr 5.999844e-04: 100% 8/8 [00:02<00:00,  3.11it/s]
# epoch 2 iter 7: train loss 0.60480. lr 5.999351e-04: 100% 8/8 [00:02<00:00,  3.21it/s]
# epoch 3 iter 7: train loss 0.50978. lr 5.998521e-04: 100% 8/8 [00:02<00:00,  3.19it/s]
# epoch 4 iter 7: train loss 0.44258. lr 5.997352e-04: 100% 8/8 [00:02<00:00,  3.17it/s]
# epoch 5 iter 7: train loss 0.37022. lr 5.995847e-04: 100% 8/8 [00:02<00:00,  3.10it/s]
# ...

# %%
# !python3 src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.finetune.params --eval_corpus_path birth_dev.tsv --outputs_path vanilla.pretrain.dev.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# 500it [00:41, 12.19it/s]
# Correct: 96.0 out of 500.0: 19.2%

# %%
# !python3 src/run.py evaluate vanilla wiki.txt --reading_params_path vanilla.finetune.params --eval_corpus_path birth_test_inputs.tsv --outputs_path vanilla.pretrain.test.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3323392
# 437it [00:36, 12.00it/s]
# No gold birth places provided; returning (0,0)
# Predictions written to vanilla.pretrain.test.predictions; no targets provided

# %% [markdown]
# ## Part g

# %%
# !python3 src/run.py pretrain synthesizer wiki.txt --writing_params_path synthesizer.pretrain.params
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# data has 418351 characters, 256 unique.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 22: train loss 3.46451. lr 5.999656e-03: 100% 23/23 [00:03<00:00,  6.29it/s]
# epoch 2 iter 22: train loss 3.24434. lr 5.998583e-03: 100% 23/23 [00:03<00:00,  6.42it/s]
# epoch 3 iter 22: train loss 3.01210. lr 5.996782e-03: 100% 23/23 [00:03<00:00,  6.39it/s]
# epoch 4 iter 22: train loss 2.92628. lr 5.994254e-03: 100% 23/23 [00:03<00:00,  6.40it/s]
# ...

# %%
# !python3 src/run.py finetune synthesizer wiki.txt --reading_params_path synthesizer.pretrain.params --writing_params_path synthesizer.finetune.params --finetune_corpus_path birth_places_train.tsv
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# epoch 1 iter 7: train loss 0.80326. lr 5.999844e-04: 100% 8/8 [00:02<00:00,  3.06it/s]
# epoch 2 iter 7: train loss 0.65491. lr 5.999351e-04: 100% 8/8 [00:02<00:00,  3.16it/s]
# epoch 3 iter 7: train loss 0.58350. lr 5.998521e-04: 100% 8/8 [00:02<00:00,  3.13it/s]
# epoch 4 iter 7: train loss 0.54769. lr 5.997352e-04: 100% 8/8 [00:02<00:00,  3.20it/s]
# epoch 5 iter 7: train loss 0.50348. lr 5.995847e-04: 100% 8/8 [00:02<00:00,  3.10it/s]
# ...

# %%
# !python3 src/run.py evaluate synthesizer wiki.txt --reading_params_path synthesizer.finetune.params --eval_corpus_path birth_dev.tsv --outputs_path synthesizer.pretrain.dev.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# 500it [00:38, 12.95it/s]
# Correct: 46.0 out of 500.0: 9.2%

# %%
# !python3 src/run.py evaluate synthesizer wiki.txt --reading_params_path synthesizer.finetune.params --eval_corpus_path birth_test_inputs.tsv --outputs_path synthesizer.pretrain.test.predictions
# Out:
# data has 418352 characters, 256 unique.
# number of parameters: 3076988
# 437it [00:33, 13.03it/s]
# No gold birth places provided; returning (0,0)
# Predictions written to synthesizer.pretrain.test.predictions; no targets provided
